# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 1)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# Approximately 6 million people visit the National Parks in the state of Utah every year.  The number of visitors increased 17% between 2017 and 2018 from 5.6 million visitors to 6.6 million visitors.  Of all the National Parks in Utah, Zion National Park is the most popular with 4.3 million visitors in 2018.  **Zion National Park** is loacated in **Washington County** in Utah which is in the southwest corner of the state.
#
# According to Chefspencil.com, Mexican Cuisine is the most popular ethnic cuisine in 27 of the 50 United States. (54%)
# https://www.chefspencil.com/most-popular-ethnic-cuisines-in-america/
#
# ![image.png](attachment:image.png)
#
# The goal of this project is two-fold.  The first goal is to find the best location to open a new **Mexican restaurant** in **Washington County, Utah.**
#
# We will use our data science powers to generate a few most promissing neighborhoods based on this criteria. Advantages of each area will then be clearly expressed so that best possible final location can be chosen by stakeholders.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Based on definition of our problem, factors that will influence our decision are:
# * number of existing restaurants in the neighborhood (any type of restaurant)
# * number of and distance to Mexican restaurants in the neighborhood, if any
# * distance of neighborhood from city center
#
# We aquired the list of all cities and zip codes with latitude and longitude from the website:
# https://www.unitedstateszipcodes.org/zip-code-database/
#
# To narrow down our area of focus, We used visitor statistics from a **State of Utah’s Travel and Tourism Industry** study performed by the Kem C. Gardner Policy Institute of the University of Utah.
# https://travel.utah.gov/wp-content/uploads/2019-TTtrifold-Updated.pdf
#
# The number of restaurants and their type and location in every neighborhood will be obtained using **Foursquare API**

# %%
##!pip install conda
# !pip install geopy
# !pip install folium

##import numpy as np # library to handle data in a vectorized manner
import pandas as pd # library for data analsysis

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

##import matplotlib.cm as cm
##import matplotlib.colors as colors

##from sklearn.cluster import KMeans

import folium # map rendering library


df_zipsall = pd.read_csv('zip_code_database.csv') 
df_zipsall.shape
# Out:
# Requirement already satisfied: geopy in c:\users\horan\anaconda3\lib\site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\horan\anaconda3\lib\site-packages (from geopy) (1.50)
# Requirement already satisfied: folium in c:\users\horan\anaconda3\lib\site-packages (0.11.0)
# Requirement already satisfied: numpy in c:\users\horan\anaconda3\lib\site-packages (from folium) (1.18.1)
# Requirement already satisfied: jinja2>=2.9 in c:\users\horan\anaconda3\lib\site-packages (from folium) (2.11.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\horan\anaconda3\lib\site-packages (from folium) (0.4.1)
# Requirement already satisfied: requests in c:\users\horan\anaconda3\lib\site-packages (from folium) (2.22.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\horan\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\horan\anaconda3\lib\site-packages (from requests->folium) (2019.11.28)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\horan\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\horan\anaconda3\lib\site-packages (from requests->folium) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\horan\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# (42632, 15)

# %%
df_zipsall.head()
# Out:
#    zip      type  decommissioned primary_city acceptable_cities  \
# 0  501    UNIQUE               0   Holtsville               NaN
# 1  544    UNIQUE               0   Holtsville               NaN
# 2  601  STANDARD               0     Adjuntas               NaN
# 3  602  STANDARD               0       Aguada               NaN
# 4  603  STANDARD               0    Aguadilla             Ramey
#
#                                  unacceptable_cities state  \
# 0                               I R S Service Center    NY
# 1                                 Irs Service Center    NY
# 2  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR
# 3  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR
# 4  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR
#
#                 county             timezone area_codes world_region country  \
# 0       Suffolk County     America/New_York        631          NaN      US
# 1       Suffolk County     America/New_York        631          NaN      US
# 2   Adjuntas Municipio  America/Puerto_Rico    787,939          NaN      US
# 3     Aguada Municipio  America/Puerto_Rico    787,939          NaN      US
# 4  Aguadilla Municipio  America/Puerto_Rico        787          NaN      US
#
#    latitude  longitude  irs_estimated_population_2015
# 0     40.81     -73.04                            562
# 1     40.81     -73.04                              0
# 2     18.16     -66.72                              0
# 3     18.38     -67.18                              0
# 4     18.43     -67.15                              0

# %%
df_zipsall.drop(['acceptable_cities', 'unacceptable_cities', 'timezone'], axis=1, inplace=True)

# %%
df_zipsall.rename(columns={"decommissioned": "decomm", "primary_city": "city", "irs_estimated_population_2015": "population2015"}, inplace=True)

# %%
df_zipsut = df_zipsall[(df_zipsall['state'] == 'UT')].reset_index(drop=True)

df_zipsut = df_zipsut[(df_zipsut['county'] == 'Washington County')].reset_index(drop=True)


df_zipsut
# Out:
#       zip      type  decomm             city state             county  \
# 0   84722  STANDARD       0          Central    UT  Washington County
# 1   84725    PO BOX       0       Enterprise    UT  Washington County
# 2   84733  STANDARD       0          Gunlock    UT  Washington County
# 3   84737  STANDARD       0        Hurricane    UT  Washington County
# 4   84738  STANDARD       0            Ivins    UT  Washington County
# 5   84745  STANDARD       0        La Verkin    UT  Washington County
# 6   84746    PO BOX       0            Leeds    UT  Washington County
# 7   84757  STANDARD       0      New Harmony    UT  Washington County
# 8   84763    PO BOX       0        Rockville    UT  Washington County
# 9   84765  STANDARD       0      Santa Clara    UT  Washington County
# 10  84767    PO BOX       0       Springdale    UT  Washington County
# 11  84770  STANDARD       0     Saint George    UT  Washington County
# 12  84771    PO BOX       0     Saint George    UT  Washington County
# 13  84774  STANDARD       0      Toquerville    UT  Washington County
# 14  84779  STANDARD       0           Virgin    UT  Washington County
# 15  84780  STANDARD       0       Washington    UT  Washington County
# 16  84781  STANDARD       0      Pine Valley    UT  Washington County
# 17  84782  STANDARD       0             Veyo    UT  Washington County
# 18  84783  STANDARD       0  Dammeron Valley    UT  Washington County
# 19  84784    PO BOX       0          Hildale    UT  Washington County
# 20  84790  STANDARD       0     Saint George    UT  Washington County
# 21  84791    PO BOX       0     Saint George    UT  Washington County
#
#    area_codes world_region country  latitude  longitude  population2015
# 0         435          NaN      US     37.39    -113.63             470
# 1         435          NaN      US     37.52    -113.75            1718
# 2         435          NaN      US     37.24    -113.79             106
# 3         435          NaN      US     37.04    -113.21           15120
# 4         435          NaN      US     37.18    -113.71            6810
# 5         435          NaN      US     37.23    -113.24            3880
# 6         435          NaN      US     37.23    -113.36             964
# 7         435          NaN      US     37.46    -113.26            1110
# 8         435          NaN      US     37.15    -113.05             168
# 9         435          NaN      US     37.13    -113.65            6600
# 10        435          NaN      US     37.25    -112.99             625
# 11        435          NaN      US     37.18    -113.60           36370
# 12        435          NaN      US     37.13    -113.48            1369
# 13        435          NaN      US     37.26    -113.27            1350
# 14        435          NaN      US     37.33    -113.12             470
# 15        435          NaN      US     37.13    -113.49           21100
# 16        435          NaN      US     37.41    -113.46             120
# 17        435          NaN      US     37.35    -113.66             710
# 18        435          NaN      US     37.26    -113.69             780
# 19        435          NaN      US     37.03    -112.96            2671
# 20        435          NaN      US     37.06    -113.57           38280
# 21        435          NaN      US     37.08    -113.55             894

# %%
address = 'Springdale, Utah'

geolocator = Nominatim(user_agent="tor_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Utah are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Utah are 37.182802800000005, -113.00212093620803.

# %%
map_utah = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, label in zip(df_zipsut['latitude'], df_zipsut['longitude'], df_zipsut['city']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_utah)  
    
map_utah
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
CLIENT_ID = 'FTSFPNKDGW1UEYRWM5IUOEDCEETWICHPW0AJKFF4RKPZQ0JT' # your Foursquare ID
CLIENT_SECRET = 'XNOIIIQFCLCN4ZWP25KOJHKLL35CY0HAX4ZARSH12BNUS53C' # your Foursquare Secret
VERSION = '20180831' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: FTSFPNKDGW1UEYRWM5IUOEDCEETWICHPW0AJKFF4RKPZQ0JT
# CLIENT_SECRET:XNOIIIQFCLCN4ZWP25KOJHKLL35CY0HAX4ZARSH12BNUS53C

# %%
neighborhood_latitude = latitude
neighborhood_longitude = longitude

neighborhood_name = address

print('Latitude and longitude values of {} are {}, {}.'.format(neighborhood_name, 
                                                               neighborhood_latitude, 
                                                               neighborhood_longitude))
# Out:
# Latitude and longitude values of Springdale, Utah are 37.182802800000005, -113.00212093620803.

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 40250 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighborhood_latitude, 
    neighborhood_longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=FTSFPNKDGW1UEYRWM5IUOEDCEETWICHPW0AJKFF4RKPZQ0JT&client_secret=XNOIIIQFCLCN4ZWP25KOJHKLL35CY0HAX4ZARSH12BNUS53C&v=20180831&ll=37.182802800000005,-113.00212093620803&radius=40250&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f51aa44edbb5d0711f3b4d6'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': '$-$$$$', 'key': 'price'},
#     {'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Springdale',
#   'headerFullLocation': 'Springdale',
#   'headerLocationGranularity': 'city',
#   'totalResults': 103,
#   'suggestedBounds': {'ne': {'lat': 37.54505316225037,
#     'lng': -112.54828781481179},
#    'sw': {'lat': 36.82055243774964, 'lng': -113.45595405760427}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5810d27e38fa6ecbf569acb1',
#        'name': "King's Landing Bistro",
#        'location': {'address': '1515 Zion Park Blvd',
#         'lat': 37.17992239203187,
#         'lng': -113.00623292298661,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.17992239203187,
#           'lng': -113.00623292298661},
#          {'label': 'entrance', 'lat': 37.179909, 'lng': -113.006275}],
#         'distance': 485,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['1515 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5810d27e38fa6ecbf569acb1-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba3c8abf964a520e05e38e3',
#        'name': 'Zion National Park',
#        'location': {'address': 'Highway SR 9',
#         'lat': 37.19927513893534,
#         'lng': -112.98904906492322,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19927513893534,
#           'lng': -112.98904906492322}],
#         'distance': 2169,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Highway SR 9',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a21',
#          'name': 'National Park',
#          'pluralName': 'National Parks',
#          'shortName': 'National Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba3c8abf964a520e05e38e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50242547e4b0783685b6793b',
#        'name': 'Zion National Park Visitor Center',
#        'location': {'address': 'Floor of the Valley Rd',
#         'lat': 37.20027050724792,
#         'lng': -112.98693917080382,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.20027050724792,
#           'lng': -112.98693917080382}],
#         'distance': 2365,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Floor of the Valley Rd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4f4530164b9074f6e4fb00ff',
#          'name': 'Tourist Information Center',
#          'pluralName': 'Tourist Information Centers',
#          'shortName': 'Tourist Information',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/touristinformation_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50242547e4b0783685b6793b-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc935e70687ef3bc2b2d9cc',
#        'name': 'Desert Pearl Inn',
#        'location': {'address': '707 Zion Park Blvd',
#         'lat': 37.19051,
#         'lng': -112.99442,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19051,
#           'lng': -112.99442},
#          {'label': 'entrance', 'lat': 37.1904, 'lng': -112.994332}],
#         'distance': 1096,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['707 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d12f951735',
#          'name': 'Resort',
#          'pluralName': 'Resorts',
#          'shortName': 'Resort',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc935e70687ef3bc2b2d9cc-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50bf7981e4b0520fba2a7674',
#        'name': 'Deep Creek Coffee',
#        'location': {'address': '932 Zion Park Blvd',
#         'crossStreet': 'Winderland Drive',
#         'lat': 37.18899441117955,
#         'lng': -113.00000870462837,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.18899441117955,
#           'lng': -113.00000870462837}],
#         'distance': 714,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['932 Zion Park Blvd (Winderland Drive)',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '76895918'}},
#       'referralId': 'e-0-50bf7981e4b0520fba2a7674-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b8d3de0f964a52061ef32e3',
#        'name': "Oscar's Cafe",
#        'location': {'address': '948 Zion Park Blvd',
#         'lat': 37.1890433205164,
#         'lng': -113.00016771449017,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.1890433205164,
#           'lng': -113.00016771449017}],
#         'distance': 715,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['948 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'shortName': 'Mexican',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b8d3de0f964a52061ef32e3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5195b05a498eb35b3e7a87c4',
#        'name': 'Hampton Inn & Suites',
#        'location': {'address': '1127 Zion Park Blvd',
#         'lat': 37.18495244285297,
#         'lng': -113.0012995004654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.18495244285297,
#           'lng': -113.0012995004654}],
#         'distance': 250,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['1127 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5195b05a498eb35b3e7a87c4-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c154e6fa1010f475cd94d18',
#        'name': 'Watchman Campground',
#        'location': {'address': 'Zion National Park',
#         'lat': 37.196753100055275,
#         'lng': -112.98658242237092,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.196753100055275,
#           'lng': -112.98658242237092}],
#         'distance': 2076,
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Zion National Park',
#          'Springdale, UT',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e4941735',
#          'name': 'Campground',
#          'pluralName': 'Campgrounds',
#          'shortName': 'Campground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/campground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c154e6fa1010f475cd94d18-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0daf6bc700c9b6d8dca2dd',
#        'name': 'Bit & Spur Restaurant & Saloon',
#        'location': {'address': '1212 Zion Park Blvd.',
#         'lat': 37.18465774833335,
#         'lng': -113.00315831259977,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.18465774833335,
#           'lng': -113.00315831259977}],
#         'distance': 226,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['1212 Zion Park Blvd.',
#          'Springdale, UT 84737',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0daf6bc700c9b6d8dca2dd-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '590c26254f0e587e87444444',
#        'name': 'Springhill Suites by Marriott',
#        'location': {'address': '1141 Canyon Springs Drive',
#         'lat': 37.1844714,
#         'lng': -113.0006139,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.1844714,
#           'lng': -113.0006139}],
#         'distance': 228,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['1141 Canyon Springs Drive',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-590c26254f0e587e87444444-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5975c05d1fa7632be286d2ff',
#        'name': 'Canyon Overlook Trail',
#        'location': {'lat': 37.213918,
#         'lng': -112.942587,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.213918,
#           'lng': -112.942587}],
#         'distance': 6313,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Hurricane',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Hurricane, UT 84737', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5975c05d1fa7632be286d2ff-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c5ef7122815c9286bf3b867',
#        'name': 'Canyon Overlook',
#        'location': {'lat': 37.18930974529718,
#         'lng': -112.98989842597611,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.18930974529718,
#           'lng': -112.98989842597611}],
#         'distance': 1303,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Apple Valley',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Apple Valley, UT 84767', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c5ef7122815c9286bf3b867-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb601333ac93704a283d00a',
#        'name': 'Park House Cafe',
#        'location': {'address': '1880 Zion Park boulevard',
#         'lat': 37.174856562934906,
#         'lng': -113.01134927859083,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.174856562934906,
#           'lng': -113.01134927859083}],
#         'distance': 1205,
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['1880 Zion Park boulevard',
#          'Springdale, UT',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb601333ac93704a283d00a-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51265f3239501b4251025ac5',
#        'name': 'La Quinta Inn & Suites at Zion Park/Springdale',
#        'location': {'address': '792 Zion Park Boulevard',
#         'lat': 37.19033794,
#         'lng': -112.9964972,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19033794,
#           'lng': -112.9964972}],
#         'distance': 975,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['792 Zion Park Boulevard',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '558866327'}},
#       'referralId': 'e-0-51265f3239501b4251025ac5-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4f1aaf2271a1bdc3da9aaf',
#        'name': 'Watchman Trail',
#        'location': {'lat': 37.201648752547634,
#         'lng': -112.97440054133654,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.201648752547634,
#           'lng': -112.97440054133654}],
#         'distance': 3231,
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Springdale, UT', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e4f1aaf2271a1bdc3da9aaf-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c39e9da18e72d7f61e81af5',
#        'name': 'Cafe Soleil',
#        'location': {'address': '205 Zion Park Blvd.',
#         'lat': 37.19778293380397,
#         'lng': -112.99129447166537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19778293380397,
#           'lng': -112.99129447166537},
#          {'label': 'entrance', 'lat': 37.1978, 'lng': -112.991364}],
#         'distance': 1924,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['205 Zion Park Blvd.',
#          'Springdale, UT 84737',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c39e9da18e72d7f61e81af5-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '518051b1e4b01a525afd1a3d',
#        'name': 'Zion Canyon Brewery',
#        'location': {'address': '2400 Zion Park Blvd',
#         'lat': 37.19930039885598,
#         'lng': -112.989013178946,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19930039885598,
#           'lng': -112.989013178946}],
#         'distance': 2173,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['2400 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-518051b1e4b01a525afd1a3d-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd0a9401f89ce7221c467ea',
#        'name': 'Cliffrose Lodge & Gardens, Curio Collection by Hilton',
#        'location': {'address': '281 Zion Park Blvd',
#         'lat': 37.19709459827103,
#         'lng': -112.99174174736021,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19709459827103,
#           'lng': -112.99174174736021},
#          {'label': 'entrance', 'lat': 37.197248, 'lng': -112.99097}],
#         'distance': 1838,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['281 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '36174663'}},
#       'referralId': 'e-0-4bd0a9401f89ce7221c467ea-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c366ff70a71c9b6e7313dc9',
#        'name': 'Zion Pizza & Noodle Co.',
#        'location': {'address': '868 Zion Park Blvd',
#         'crossStreet': 'S Paradise Rd',
#         'lat': 37.1892759206649,
#         'lng': -112.99850399763568,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.1892759206649,
#           'lng': -112.99850399763568}],
#         'distance': 788,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['868 Zion Park Blvd (S Paradise Rd)',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c366ff70a71c9b6e7313dc9-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57f145a4498e8431c933fd66',
#        'name': 'Springdale & Zion Canyon Visitor Center',
#        'location': {'lat': 37.18614006126597,
#         'lng': -113.0016225536374,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.18614006126597,
#           'lng': -113.0016225536374}],
#         'distance': 374,
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Springdale, UT', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d128951735',
#          'name': 'Gift Shop',
#          'pluralName': 'Gift Shops',
#          'shortName': 'Gift Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57f145a4498e8431c933fd66-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1fc1e2eac020a124954bc2',
#        'name': 'Zion Adventure Company',
#        'location': {'address': '36 Lion Blvd',
#         'crossStreet': 'Zion Park Blvd',
#         'lat': 37.19407323257579,
#         'lng': -112.99377642319367,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19407323257579,
#           'lng': -112.99377642319367}],
#         'distance': 1456,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['36 Lion Blvd (Zion Park Blvd)',
#          'Springdale, UT 84737',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f2941735',
#          'name': 'Sporting Goods Shop',
#          'pluralName': 'Sporting Goods Shops',
#          'shortName': 'Sporting Goods',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1fc1e2eac020a124954bc2-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1f81fc8b3aa593198c9d5f',
#        'name': 'Bumbleberry Gifts',
#        'location': {'address': '897 Zion Park Blvd',
#         'lat': 37.188578526522555,
#         'lng': -112.99911449327217,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.188578526522555,
#           'lng': -112.99911449327217},
#          {'label': 'entrance', 'lat': 37.188783, 'lng': -112.998964}],
#         'distance': 696,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['897 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d128951735',
#          'name': 'Gift Shop',
#          'pluralName': 'Gift Shops',
#          'shortName': 'Gift Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c1f81fc8b3aa593198c9d5f-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ce02bbfdf986ea82c00e616',
#        'name': "Angel's Landing",
#        'location': {'address': "37° 16.16', 112° 56.92'",
#         'crossStreet': 'The Grotto Trailhead Dropoff',
#         'lat': 37.26933298259414,
#         'lng': -112.94790337827106,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.26933298259414,
#           'lng': -112.94790337827106}],
#         'distance': 10764,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Zion Canyon',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ["37° 16.16', 112° 56.92' (The Grotto Trailhead Dropoff)",
#          'Zion Canyon, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ce02bbfdf986ea82c00e616-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4db32c36f7b121c29f31255d',
#        'name': 'Observation Point',
#        'location': {'address': 'Weeping Rock Trailhead',
#         'crossStreet': 'at Zion National Park',
#         'lat': 37.27829414125782,
#         'lng': -112.94037666462344,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.27829414125782,
#           'lng': -112.94037666462344}],
#         'distance': 11955,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Zion',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Weeping Rock Trailhead (at Zion National Park)',
#          'Zion, UT 84737',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4db32c36f7b121c29f31255d-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51cb45eb498e592307859608',
#        'name': 'Checkerboard Mesa',
#        'location': {'lat': 37.226308030213495,
#         'lng': -112.88008083334353,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.226308030213495,
#           'lng': -112.88008083334353}],
#         'distance': 11854,
#         'cc': 'US',
#         'city': 'Zion Lodge',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Zion Lodge, UT', 'United States']},
#        'categories': [{'id': '4eb1d4d54b900d56c88a45fc',
#          'name': 'Mountain',
#          'pluralName': 'Mountains',
#          'shortName': 'Mountain',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51cb45eb498e592307859608-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e4e5590bd4101d0d7a7f190',
#        'name': 'Switchback Grille',
#        'location': {'address': '1149 Zion Park Blvd',
#         'lat': 37.18407217279923,
#         'lng': -113.00254761712111,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.18407217279923,
#           'lng': -113.00254761712111}],
#         'distance': 146,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['1149 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '424630316'}},
#       'referralId': 'e-0-4e4e5590bd4101d0d7a7f190-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d33a07c8c42a1cd1eebf35d',
#        'name': "Switchback Jack's",
#        'location': {'address': '1149 Zion Park Blvd',
#         'lat': 37.183833857749846,
#         'lng': -113.00253360646207,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.183833857749846,
#           'lng': -113.00253360646207},
#          {'label': 'entrance', 'lat': 37.183865, 'lng': -113.002568}],
#         'distance': 120,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['1149 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'shortName': 'American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d33a07c8c42a1cd1eebf35d-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd5efbd9649ce7276b7511d',
#        'name': 'Majestic View Lodge & Steakhouse',
#        'location': {'address': '2400 Zion Park Blvd',
#         'lat': 37.166700344204564,
#         'lng': -113.01423406924033,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.166700344204564,
#           'lng': -113.01423406924033},
#          {'label': 'entrance', 'lat': 37.167647, 'lng': -113.014096}],
#         'distance': 2089,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['2400 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '62496966'}},
#       'referralId': 'e-0-4bd5efbd9649ce7276b7511d-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a5590be4b038a5b1a81107',
#        'name': "Pa'rus Trail",
#        'location': {'lat': 37.20721725600407,
#         'lng': -112.98018307944105,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.20721725600407,
#           'lng': -112.98018307944105}],
#         'distance': 3342,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Springdale, UT 84767', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50a5590be4b038a5b1a81107-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2006e563750f474b13bc67',
#        'name': 'Spotted Dog Cafe',
#        'location': {'address': '428 Zion Park Blvd',
#         'lat': 37.19476425685609,
#         'lng': -112.99325800209994,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19476425685609,
#           'lng': -112.99325800209994}],
#         'distance': 1546,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['428 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d143941735',
#          'name': 'Breakfast Spot',
#          'pluralName': 'Breakfast Spots',
#          'shortName': 'Breakfast',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c2006e563750f474b13bc67-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50de1adde4b0869e4ef2983c',
#        'name': 'Emerald Pools Falls',
#        'location': {'lat': 37.251267707886825,
#         'lng': -112.956499264191,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.251267707886825,
#           'lng': -112.956499264191}],
#         'distance': 8628,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Springdale, UT 84767', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50de1adde4b0869e4ef2983c-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5975c12e1f8ed660bb2f51aa',
#        'name': 'Angels Landing Trail',
#        'location': {'lat': 37.274294,
#         'lng': -112.950469,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.274294,
#           'lng': -112.950469}],
#         'distance': 11166,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Hurricane',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Hurricane, UT 84737', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5975c12e1f8ed660bb2f51aa-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c95697c38dd8cfaefc8d262',
#        'name': 'Springdale Candy Company',
#        'location': {'address': '855a Zion Park Blvd',
#         'lat': 37.18895732754412,
#         'lng': -112.99826144111607,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.18895732754412,
#           'lng': -112.99826144111607},
#          {'label': 'entrance', 'lat': 37.188908, 'lng': -112.998188}],
#         'distance': 765,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['855a Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c95697c38dd8cfaefc8d262-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e14c5fa8130fea02877110e',
#        'name': 'The Narrows of Zion Canyon',
#        'location': {'address': '37.3624°N 112.8492°W',
#         'lat': 37.301062582388106,
#         'lng': -112.94635444879532,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.301062582388106,
#           'lng': -112.94635444879532}],
#         'distance': 14061,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['37.3624°N 112.8492°W',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e14c5fa8130fea02877110e-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7e48a6f0b09c74eee23f7c',
#        'name': 'Cable Mountain Lodge',
#        'location': {'address': '147 Zion Park Blvd',
#         'lat': 37.1990462,
#         'lng': -112.9890285,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.1990462,
#           'lng': -112.9890285},
#          {'label': 'entrance', 'lat': 37.198678, 'lng': -112.989387}],
#         'distance': 2148,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['147 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7e48a6f0b09c74eee23f7c-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc428d7dce4eee137fb719d',
#        'name': 'Zion Ponderosa Ranch Resort',
#        'location': {'address': 'Twin Knolls Rd',
#         'lat': 37.2750621,
#         'lng': -112.8821911,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.2750621,
#           'lng': -112.8821911}],
#         'distance': 14780,
#         'postalCode': '84758',
#         'cc': 'US',
#         'city': 'Orderville',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Twin Knolls Rd',
#          'Orderville, UT 84758',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d12f951735',
#          'name': 'Resort',
#          'pluralName': 'Resorts',
#          'shortName': 'Resort',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc428d7dce4eee137fb719d-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc428eedce4eee142fb719d',
#        'name': "Flanigan's Inn and Restaurant",
#        'location': {'address': '450 Zion Park Blvd.',
#         'lat': 37.19466391287769,
#         'lng': -112.99372789727026,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19466391287769,
#           'lng': -112.99372789727026}],
#         'distance': 1515,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['450 Zion Park Blvd.',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bc428eedce4eee142fb719d-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '502a9bf2e4b06b23dfc37e3f',
#        'name': "MeMe's Cafe",
#        'location': {'address': '975 Zion Park Blvd',
#         'lat': 37.188437515471264,
#         'lng': -113.0001134902416,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.188437515471264,
#           'lng': -113.0001134902416}],
#         'distance': 652,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['975 Zion Park Blvd',
#          'Springdale, UT 84767',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-502a9bf2e4b06b23dfc37e3f-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5920ee7dda2e0075ae99459b',
#        'name': 'Zion Outfitter',
#        'location': {'lat': 37.19956648316862,
#         'lng': -112.98888134300687,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.19956648316862,
#           'lng': -112.98888134300687}],
#         'distance': 2204,
#         'postalCode': '84767',
#         'cc': 'US',
#         'city': 'Springdale',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Springdale, UT 84767', 'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b22',
#          'name': 'Outdoor Supply Store',
#          'pluralName': 'Outdoor Supply Stores',
#          'shortName': 'Outdoor Supplies',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5920ee7dda2e0075ae99459b-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51d463e6498e8ee4dbe1d9ee',
#        'name': 'Temple Of Sinawava',
#        'location': {'lat': 37.2842442619694,
#         'lng': -112.9468419938433,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.2842442619694,
#           'lng': -112.9468419938433}],
#         'distance': 12309,
#         'postalCode': '84767',
#         'cc': 'US',
#         'state': 'Utah',
#         'country': 'United States',
#         'formattedAddress': ['UT 84767', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
# ...
#        'name': "Papa Murphy's",
#        'location': {'address': '535 W State St',
#         'lat': 37.1762994,
#         'lng': -113.2987578,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 37.176315,
#           'lng': -113.29872},
#          {'label': 'display', 'lat': 37.1762994, 'lng': -113.2987578}],
#         'distance': 26319,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Hurricane',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['535 W State St',
#          'Hurricane, UT 84737',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e053cd7b0fbba5eee0e135c-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bbca66007809521fc87d991',
#        'name': 'Subway',
#        'location': {'address': '525 W State St',
#         'lat': 37.17630043519847,
#         'lng': -113.29837270650329,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.17630043519847,
#           'lng': -113.29837270650329}],
#         'distance': 26285,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Hurricane',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['525 W State St',
#          'Hurricane, UT 84737',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c5941735',
#          'name': 'Sandwich Place',
#          'pluralName': 'Sandwich Places',
#          'shortName': 'Sandwiches',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bbca66007809521fc87d991-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d41f106aed776eb1bd66997',
#        'name': "Domino's Pizza",
#        'location': {'address': '410 W State St',
#         'lat': 37.1767947,
#         'lng': -113.2958718,
#         'labeledLatLngs': [{'label': 'entrance',
#           'lat': 37.176748,
#           'lng': -113.295867},
#          {'label': 'display', 'lat': 37.1767947, 'lng': -113.2958718}],
#         'distance': 26062,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Hurricane',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['410 W State St',
#          'Hurricane, UT 84737',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d41f106aed776eb1bd66997-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfefd0666ee9eb0fa28a74e',
#        'name': 'U.S. Bank ATM',
#        'location': {'address': '1060 W State St',
#         'lat': 37.176792,
#         'lng': -113.307938,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.176792,
#           'lng': -113.307938},
#          {'label': 'entrance', 'lat': 37.1767, 'lng': -113.307921}],
#         'distance': 27131,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Hurricane',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['1060 W State St',
#          'Hurricane, UT 84737',
#          'United States']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b56',
#          'name': 'ATM',
#          'pluralName': 'ATMs',
#          'shortName': 'ATM',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfefd0666ee9eb0fa28a74e-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ab86c61f964a520f87c20e3',
#        'name': 'Rodeway Inn',
#        'location': {'address': '650 W State St',
#         'lat': 37.176729,
#         'lng': -113.2988775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.176729,
#           'lng': -113.2988775},
#          {'label': 'entrance', 'lat': 37.176694, 'lng': -113.298874}],
#         'distance': 26328,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Hurricane',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['650 W State St',
#          'Hurricane, UT 84737',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1fb931735',
#          'name': 'Motel',
#          'pluralName': 'Motels',
#          'shortName': 'Motel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ab86c61f964a520f87c20e3-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ded5021e4cd032b18887094',
#        'name': 'United States Postal Service',
#        'location': {'address': '55 S Central St',
#         'lat': 36.989005129122525,
#         'lng': -112.97441556120248,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 36.989005129122525,
#           'lng': -112.97441556120248}],
#         'distance': 21713,
#         'postalCode': '86021',
#         'cc': 'US',
#         'city': 'Colorado City',
#         'state': 'AZ',
#         'country': 'United States',
#         'formattedAddress': ['55 S Central St',
#          'Colorado City, AZ 86021',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d172941735',
#          'name': 'Post Office',
#          'pluralName': 'Post Offices',
#          'shortName': 'Post Office',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ded5021e4cd032b18887094-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e2096521f6effe84f6846a0',
#        'name': 'Maverik',
#        'location': {'address': '460 North State Street',
#         'lat': 37.2102072,
#         'lng': -113.2712905,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.2102072,
#           'lng': -113.2712905}],
#         'distance': 24062,
#         'postalCode': '84745',
#         'cc': 'US',
#         'city': 'La Verkin',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['460 North State Street',
#          'La Verkin, UT 84745',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '568476353'}},
#       'referralId': 'e-0-4e2096521f6effe84f6846a0-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e332e247d8b6946c1ebcbaa',
#        'name': 'Coral Pink Sand Dunes State Park',
#        'location': {'lat': 37.14523596925176,
#         'lng': -112.56898416173908,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.14523596925176,
#           'lng': -112.56898416173908}],
#         'distance': 38650,
#         'cc': 'US',
#         'city': 'Kanab',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Kanab, UT', 'United States']},
#        'categories': [{'id': '5bae9231bedf3950379f89d0',
#          'name': 'State / Provincial Park',
#          'pluralName': 'State / Provincial Parks',
#          'shortName': 'State / Provincial Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e332e247d8b6946c1ebcbaa-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb9e14c7421a593c319c340',
#        'name': 'Maverik #402',
#        'location': {'address': '55 N 3400 W',
#         'lat': 37.17010489724265,
#         'lng': -113.36769714030191,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.17010489724265,
#           'lng': -113.36769714030191},
#          {'label': 'entrance', 'lat': 37.170061, 'lng': -113.367607}],
#         'distance': 32456,
#         'postalCode': '84737',
#         'cc': 'US',
#         'city': 'Hurricane',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['55 N 3400 W',
#          'Hurricane, UT 84737',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'shortName': 'Gas Station',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '559255208'}},
#       'referralId': 'e-0-4bb9e14c7421a593c319c340-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cb34bd675ebb60c3524dbad',
#        'name': 'Silver Reef Museum',
#        'location': {'address': 'Silver Reef Dr',
#         'crossStreet': 'Wells Fargo',
#         'lat': 37.25313186645508,
#         'lng': -113.36817932128906,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.25313186645508,
#           'lng': -113.36817932128906}],
#         'distance': 33381,
#         'cc': 'US',
#         'city': 'Leeds',
#         'state': 'UT',
#         'country': 'United States',
#         'formattedAddress': ['Silver Reef Dr (Wells Fargo)',
#          'Leeds, UT',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cb34bd675ebb60c3524dbad-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '523df906498e9c0a2984ac2a',
#        'name': 'Colorado City Municipal Airport',
#        'location': {'lat': 36.99596396472061,
#         'lng': -113.00373823295855,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 36.99596396472061,
#           'lng': -113.00373823295855}],
#         'distance': 20799,
#         'cc': 'US',
#         'city': 'Colorado City',
#         'state': 'AZ',
#         'country': 'United States',
#         'formattedAddress': ['Colorado City, AZ', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ed931735',
#          'name': 'Airport',
#          'pluralName': 'Airports',
#          'shortName': 'Airport',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-523df906498e9c0a2984ac2a-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b4ea00792e7a9002ccc0a55',
#        'name': 'Edge Of The World Brewery',
#        'location': {'address': '70 N Central St.',
#         'lat': 36.991281,
#         'lng': -112.973656,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 36.991281,
#           'lng': -112.973656}],
#         'distance': 21469,
#         'postalCode': '86021',
#         'cc': 'US',
#         'city': 'Colorado City',
#         'state': 'AZ',
#         'country': 'United States',
#         'formattedAddress': ['70 N Central St.',
#          'Colorado City, AZ 86021',
#          'United States']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5b4ea00792e7a9002ccc0a55-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bb928851261d13a3465e998',
#        'name': "Dixie Nat'l Forest @ Silver Reef",
#        'location': {'lat': 37.27272323403318,
#         'lng': -113.38871827265274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.27272323403318,
#           'lng': -113.38871827265274}],
#         'distance': 35698,
#         'cc': 'US',
#         'state': 'Utah',
#         'country': 'United States',
#         'formattedAddress': ['Utah', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bb928851261d13a3465e998-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5401edfa498e46786b10f27d',
#        'name': 'Hurricane Sand Dunes',
#        'location': {'lat': 37.078962,
#         'lng': -113.392777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 37.078962,
#           'lng': -113.392777}],
#         'distance': 36546,
#         'cc': 'US',
#         'state': 'Utah',
#         'country': 'United States',
#         'formattedAddress': ['Utah', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'shortName': 'Trail',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5401edfa498e46786b10f27d-99'}]}]}}

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
venues
# Out:
# [{'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5810d27e38fa6ecbf569acb1',
#    'name': "King's Landing Bistro",
#    'location': {'address': '1515 Zion Park Blvd',
#     'lat': 37.17992239203187,
#     'lng': -113.00623292298661,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.17992239203187,
#       'lng': -113.00623292298661},
#      {'label': 'entrance', 'lat': 37.179909, 'lng': -113.006275}],
#     'distance': 485,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['1515 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14e941735',
#      'name': 'American Restaurant',
#      'pluralName': 'American Restaurants',
#      'shortName': 'American',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5810d27e38fa6ecbf569acb1-0'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ba3c8abf964a520e05e38e3',
#    'name': 'Zion National Park',
#    'location': {'address': 'Highway SR 9',
#     'lat': 37.19927513893534,
#     'lng': -112.98904906492322,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19927513893534,
#       'lng': -112.98904906492322}],
#     'distance': 2169,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Highway SR 9',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '52e81612bcbc57f1066b7a21',
#      'name': 'National Park',
#      'pluralName': 'National Parks',
#      'shortName': 'National Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4ba3c8abf964a520e05e38e3-1'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50242547e4b0783685b6793b',
#    'name': 'Zion National Park Visitor Center',
#    'location': {'address': 'Floor of the Valley Rd',
#     'lat': 37.20027050724792,
#     'lng': -112.98693917080382,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.20027050724792,
#       'lng': -112.98693917080382}],
#     'distance': 2365,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Floor of the Valley Rd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4f4530164b9074f6e4fb00ff',
#      'name': 'Tourist Information Center',
#      'pluralName': 'Tourist Information Centers',
#      'shortName': 'Tourist Information',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/touristinformation_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-50242547e4b0783685b6793b-2'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bc935e70687ef3bc2b2d9cc',
#    'name': 'Desert Pearl Inn',
#    'location': {'address': '707 Zion Park Blvd',
#     'lat': 37.19051,
#     'lng': -112.99442,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19051,
#       'lng': -112.99442},
#      {'label': 'entrance', 'lat': 37.1904, 'lng': -112.994332}],
#     'distance': 1096,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['707 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d12f951735',
#      'name': 'Resort',
#      'pluralName': 'Resorts',
#      'shortName': 'Resort',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bc935e70687ef3bc2b2d9cc-3'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50bf7981e4b0520fba2a7674',
#    'name': 'Deep Creek Coffee',
#    'location': {'address': '932 Zion Park Blvd',
#     'crossStreet': 'Winderland Drive',
#     'lat': 37.18899441117955,
#     'lng': -113.00000870462837,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.18899441117955,
#       'lng': -113.00000870462837}],
#     'distance': 714,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['932 Zion Park Blvd (Winderland Drive)',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e0931735',
#      'name': 'Coffee Shop',
#      'pluralName': 'Coffee Shops',
#      'shortName': 'Coffee Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '76895918'}},
#   'referralId': 'e-0-50bf7981e4b0520fba2a7674-4'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4b8d3de0f964a52061ef32e3',
#    'name': "Oscar's Cafe",
#    'location': {'address': '948 Zion Park Blvd',
#     'lat': 37.1890433205164,
#     'lng': -113.00016771449017,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.1890433205164,
#       'lng': -113.00016771449017}],
#     'distance': 715,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['948 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c1941735',
#      'name': 'Mexican Restaurant',
#      'pluralName': 'Mexican Restaurants',
#      'shortName': 'Mexican',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b8d3de0f964a52061ef32e3-5'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5195b05a498eb35b3e7a87c4',
#    'name': 'Hampton Inn & Suites',
#    'location': {'address': '1127 Zion Park Blvd',
#     'lat': 37.18495244285297,
#     'lng': -113.0012995004654,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.18495244285297,
#       'lng': -113.0012995004654}],
#     'distance': 250,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['1127 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fa931735',
#      'name': 'Hotel',
#      'pluralName': 'Hotels',
#      'shortName': 'Hotel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5195b05a498eb35b3e7a87c4-6'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c154e6fa1010f475cd94d18',
#    'name': 'Watchman Campground',
#    'location': {'address': 'Zion National Park',
#     'lat': 37.196753100055275,
#     'lng': -112.98658242237092,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.196753100055275,
#       'lng': -112.98658242237092}],
#     'distance': 2076,
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Zion National Park',
#      'Springdale, UT',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e4941735',
#      'name': 'Campground',
#      'pluralName': 'Campgrounds',
#      'shortName': 'Campground',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/campground_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c154e6fa1010f475cd94d18-7'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c0daf6bc700c9b6d8dca2dd',
#    'name': 'Bit & Spur Restaurant & Saloon',
#    'location': {'address': '1212 Zion Park Blvd.',
#     'lat': 37.18465774833335,
#     'lng': -113.00315831259977,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.18465774833335,
#       'lng': -113.00315831259977}],
#     'distance': 226,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['1212 Zion Park Blvd.',
#      'Springdale, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14e941735',
#      'name': 'American Restaurant',
#      'pluralName': 'American Restaurants',
#      'shortName': 'American',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c0daf6bc700c9b6d8dca2dd-8'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '590c26254f0e587e87444444',
#    'name': 'Springhill Suites by Marriott',
#    'location': {'address': '1141 Canyon Springs Drive',
#     'lat': 37.1844714,
#     'lng': -113.0006139,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.1844714,
#       'lng': -113.0006139}],
#     'distance': 228,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['1141 Canyon Springs Drive',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fa931735',
#      'name': 'Hotel',
#      'pluralName': 'Hotels',
#      'shortName': 'Hotel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-590c26254f0e587e87444444-9'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5975c05d1fa7632be286d2ff',
#    'name': 'Canyon Overlook Trail',
#    'location': {'lat': 37.213918,
#     'lng': -112.942587,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.213918,
#       'lng': -112.942587}],
#     'distance': 6313,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Hurricane',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Hurricane, UT 84737', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d159941735',
#      'name': 'Trail',
#      'pluralName': 'Trails',
#      'shortName': 'Trail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5975c05d1fa7632be286d2ff-10'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c5ef7122815c9286bf3b867',
#    'name': 'Canyon Overlook',
#    'location': {'lat': 37.18930974529718,
#     'lng': -112.98989842597611,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.18930974529718,
#       'lng': -112.98989842597611}],
#     'distance': 1303,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Apple Valley',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Apple Valley, UT 84767', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d165941735',
#      'name': 'Scenic Lookout',
#      'pluralName': 'Scenic Lookouts',
#      'shortName': 'Scenic Lookout',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c5ef7122815c9286bf3b867-11'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4cb601333ac93704a283d00a',
#    'name': 'Park House Cafe',
#    'location': {'address': '1880 Zion Park boulevard',
#     'lat': 37.174856562934906,
#     'lng': -113.01134927859083,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.174856562934906,
#       'lng': -113.01134927859083}],
#     'distance': 1205,
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['1880 Zion Park boulevard',
#      'Springdale, UT',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d143941735',
#      'name': 'Breakfast Spot',
#      'pluralName': 'Breakfast Spots',
#      'shortName': 'Breakfast',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4cb601333ac93704a283d00a-12'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '51265f3239501b4251025ac5',
#    'name': 'La Quinta Inn & Suites at Zion Park/Springdale',
#    'location': {'address': '792 Zion Park Boulevard',
#     'lat': 37.19033794,
#     'lng': -112.9964972,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19033794,
#       'lng': -112.9964972}],
#     'distance': 975,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['792 Zion Park Boulevard',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fa931735',
#      'name': 'Hotel',
#      'pluralName': 'Hotels',
#      'shortName': 'Hotel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '558866327'}},
#   'referralId': 'e-0-51265f3239501b4251025ac5-13'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e4f1aaf2271a1bdc3da9aaf',
#    'name': 'Watchman Trail',
#    'location': {'lat': 37.201648752547634,
#     'lng': -112.97440054133654,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.201648752547634,
#       'lng': -112.97440054133654}],
#     'distance': 3231,
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Springdale, UT', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d159941735',
#      'name': 'Trail',
#      'pluralName': 'Trails',
#      'shortName': 'Trail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e4f1aaf2271a1bdc3da9aaf-14'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c39e9da18e72d7f61e81af5',
#    'name': 'Cafe Soleil',
#    'location': {'address': '205 Zion Park Blvd.',
#     'lat': 37.19778293380397,
#     'lng': -112.99129447166537,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19778293380397,
#       'lng': -112.99129447166537},
#      {'label': 'entrance', 'lat': 37.1978, 'lng': -112.991364}],
#     'distance': 1924,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['205 Zion Park Blvd.',
#      'Springdale, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c39e9da18e72d7f61e81af5-15'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '518051b1e4b01a525afd1a3d',
#    'name': 'Zion Canyon Brewery',
#    'location': {'address': '2400 Zion Park Blvd',
#     'lat': 37.19930039885598,
#     'lng': -112.989013178946,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19930039885598,
#       'lng': -112.989013178946}],
#     'distance': 2173,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['2400 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-518051b1e4b01a525afd1a3d-16'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bd0a9401f89ce7221c467ea',
#    'name': 'Cliffrose Lodge & Gardens, Curio Collection by Hilton',
#    'location': {'address': '281 Zion Park Blvd',
#     'lat': 37.19709459827103,
#     'lng': -112.99174174736021,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19709459827103,
#       'lng': -112.99174174736021},
#      {'label': 'entrance', 'lat': 37.197248, 'lng': -112.99097}],
#     'distance': 1838,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['281 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fa931735',
#      'name': 'Hotel',
#      'pluralName': 'Hotels',
#      'shortName': 'Hotel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '36174663'}},
#   'referralId': 'e-0-4bd0a9401f89ce7221c467ea-17'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c366ff70a71c9b6e7313dc9',
#    'name': 'Zion Pizza & Noodle Co.',
#    'location': {'address': '868 Zion Park Blvd',
#     'crossStreet': 'S Paradise Rd',
#     'lat': 37.1892759206649,
#     'lng': -112.99850399763568,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.1892759206649,
#       'lng': -112.99850399763568}],
#     'distance': 788,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['868 Zion Park Blvd (S Paradise Rd)',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c366ff70a71c9b6e7313dc9-18'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '57f145a4498e8431c933fd66',
#    'name': 'Springdale & Zion Canyon Visitor Center',
#    'location': {'lat': 37.18614006126597,
#     'lng': -113.0016225536374,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.18614006126597,
#       'lng': -113.0016225536374}],
#     'distance': 374,
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Springdale, UT', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d128951735',
#      'name': 'Gift Shop',
#      'pluralName': 'Gift Shops',
#      'shortName': 'Gift Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-57f145a4498e8431c933fd66-19'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c1fc1e2eac020a124954bc2',
#    'name': 'Zion Adventure Company',
#    'location': {'address': '36 Lion Blvd',
#     'crossStreet': 'Zion Park Blvd',
#     'lat': 37.19407323257579,
#     'lng': -112.99377642319367,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19407323257579,
#       'lng': -112.99377642319367}],
#     'distance': 1456,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['36 Lion Blvd (Zion Park Blvd)',
#      'Springdale, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1f2941735',
#      'name': 'Sporting Goods Shop',
#      'pluralName': 'Sporting Goods Shops',
#      'shortName': 'Sporting Goods',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c1fc1e2eac020a124954bc2-20'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c1f81fc8b3aa593198c9d5f',
#    'name': 'Bumbleberry Gifts',
#    'location': {'address': '897 Zion Park Blvd',
#     'lat': 37.188578526522555,
#     'lng': -112.99911449327217,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.188578526522555,
#       'lng': -112.99911449327217},
#      {'label': 'entrance', 'lat': 37.188783, 'lng': -112.998964}],
#     'distance': 696,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['897 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d128951735',
#      'name': 'Gift Shop',
#      'pluralName': 'Gift Shops',
#      'shortName': 'Gift Shop',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/giftshop_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c1f81fc8b3aa593198c9d5f-21'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ce02bbfdf986ea82c00e616',
#    'name': "Angel's Landing",
#    'location': {'address': "37° 16.16', 112° 56.92'",
#     'crossStreet': 'The Grotto Trailhead Dropoff',
#     'lat': 37.26933298259414,
#     'lng': -112.94790337827106,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.26933298259414,
#       'lng': -112.94790337827106}],
#     'distance': 10764,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Zion Canyon',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ["37° 16.16', 112° 56.92' (The Grotto Trailhead Dropoff)",
#      'Zion Canyon, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d165941735',
#      'name': 'Scenic Lookout',
#      'pluralName': 'Scenic Lookouts',
#      'shortName': 'Scenic Lookout',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4ce02bbfdf986ea82c00e616-22'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4db32c36f7b121c29f31255d',
#    'name': 'Observation Point',
#    'location': {'address': 'Weeping Rock Trailhead',
#     'crossStreet': 'at Zion National Park',
#     'lat': 37.27829414125782,
#     'lng': -112.94037666462344,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.27829414125782,
#       'lng': -112.94037666462344}],
#     'distance': 11955,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Zion',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Weeping Rock Trailhead (at Zion National Park)',
#      'Zion, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d165941735',
#      'name': 'Scenic Lookout',
#      'pluralName': 'Scenic Lookouts',
#      'shortName': 'Scenic Lookout',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4db32c36f7b121c29f31255d-23'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '51cb45eb498e592307859608',
#    'name': 'Checkerboard Mesa',
#    'location': {'lat': 37.226308030213495,
#     'lng': -112.88008083334353,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.226308030213495,
#       'lng': -112.88008083334353}],
#     'distance': 11854,
#     'cc': 'US',
#     'city': 'Zion Lodge',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Zion Lodge, UT', 'United States']},
#    'categories': [{'id': '4eb1d4d54b900d56c88a45fc',
#      'name': 'Mountain',
#      'pluralName': 'Mountains',
#      'shortName': 'Mountain',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/mountain_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-51cb45eb498e592307859608-24'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e4e5590bd4101d0d7a7f190',
#    'name': 'Switchback Grille',
#    'location': {'address': '1149 Zion Park Blvd',
#     'lat': 37.18407217279923,
#     'lng': -113.00254761712111,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.18407217279923,
#       'lng': -113.00254761712111}],
#     'distance': 146,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['1149 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c4941735',
#      'name': 'Restaurant',
#      'pluralName': 'Restaurants',
#      'shortName': 'Restaurant',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '424630316'}},
#   'referralId': 'e-0-4e4e5590bd4101d0d7a7f190-25'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d33a07c8c42a1cd1eebf35d',
#    'name': "Switchback Jack's",
#    'location': {'address': '1149 Zion Park Blvd',
#     'lat': 37.183833857749846,
#     'lng': -113.00253360646207,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.183833857749846,
#       'lng': -113.00253360646207},
#      {'label': 'entrance', 'lat': 37.183865, 'lng': -113.002568}],
#     'distance': 120,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['1149 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d14e941735',
#      'name': 'American Restaurant',
#      'pluralName': 'American Restaurants',
#      'shortName': 'American',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d33a07c8c42a1cd1eebf35d-26'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bd5efbd9649ce7276b7511d',
#    'name': 'Majestic View Lodge & Steakhouse',
#    'location': {'address': '2400 Zion Park Blvd',
#     'lat': 37.166700344204564,
#     'lng': -113.01423406924033,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.166700344204564,
#       'lng': -113.01423406924033},
#      {'label': 'entrance', 'lat': 37.167647, 'lng': -113.014096}],
#     'distance': 2089,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['2400 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fa931735',
#      'name': 'Hotel',
#      'pluralName': 'Hotels',
#      'shortName': 'Hotel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '62496966'}},
#   'referralId': 'e-0-4bd5efbd9649ce7276b7511d-27'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50a5590be4b038a5b1a81107',
#    'name': "Pa'rus Trail",
#    'location': {'lat': 37.20721725600407,
#     'lng': -112.98018307944105,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.20721725600407,
#       'lng': -112.98018307944105}],
#     'distance': 3342,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Springdale, UT 84767', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d159941735',
#      'name': 'Trail',
#      'pluralName': 'Trails',
#      'shortName': 'Trail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-50a5590be4b038a5b1a81107-28'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c2006e563750f474b13bc67',
#    'name': 'Spotted Dog Cafe',
#    'location': {'address': '428 Zion Park Blvd',
#     'lat': 37.19476425685609,
#     'lng': -112.99325800209994,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19476425685609,
#       'lng': -112.99325800209994}],
#     'distance': 1546,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['428 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d143941735',
#      'name': 'Breakfast Spot',
#      'pluralName': 'Breakfast Spots',
#      'shortName': 'Breakfast',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c2006e563750f474b13bc67-29'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '50de1adde4b0869e4ef2983c',
#    'name': 'Emerald Pools Falls',
#    'location': {'lat': 37.251267707886825,
#     'lng': -112.956499264191,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.251267707886825,
#       'lng': -112.956499264191}],
#     'distance': 8628,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Springdale, UT 84767', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d165941735',
#      'name': 'Scenic Lookout',
#      'pluralName': 'Scenic Lookouts',
#      'shortName': 'Scenic Lookout',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-50de1adde4b0869e4ef2983c-30'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5975c12e1f8ed660bb2f51aa',
#    'name': 'Angels Landing Trail',
#    'location': {'lat': 37.274294,
#     'lng': -112.950469,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.274294,
#       'lng': -112.950469}],
#     'distance': 11166,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Hurricane',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Hurricane, UT 84737', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d159941735',
#      'name': 'Trail',
#      'pluralName': 'Trails',
#      'shortName': 'Trail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5975c12e1f8ed660bb2f51aa-31'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c95697c38dd8cfaefc8d262',
#    'name': 'Springdale Candy Company',
#    'location': {'address': '855a Zion Park Blvd',
#     'lat': 37.18895732754412,
#     'lng': -112.99826144111607,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.18895732754412,
#       'lng': -112.99826144111607},
#      {'label': 'entrance', 'lat': 37.188908, 'lng': -112.998188}],
#     'distance': 765,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['855a Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c9941735',
#      'name': 'Ice Cream Shop',
#      'pluralName': 'Ice Cream Shops',
#      'shortName': 'Ice Cream',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c95697c38dd8cfaefc8d262-32'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e14c5fa8130fea02877110e',
#    'name': 'The Narrows of Zion Canyon',
#    'location': {'address': '37.3624°N 112.8492°W',
#     'lat': 37.301062582388106,
#     'lng': -112.94635444879532,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.301062582388106,
#       'lng': -112.94635444879532}],
#     'distance': 14061,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['37.3624°N 112.8492°W',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d159941735',
#      'name': 'Trail',
#      'pluralName': 'Trails',
#      'shortName': 'Trail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e14c5fa8130fea02877110e-33'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c7e48a6f0b09c74eee23f7c',
#    'name': 'Cable Mountain Lodge',
#    'location': {'address': '147 Zion Park Blvd',
#     'lat': 37.1990462,
#     'lng': -112.9890285,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.1990462,
#       'lng': -112.9890285},
#      {'label': 'entrance', 'lat': 37.198678, 'lng': -112.989387}],
#     'distance': 2148,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['147 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fa931735',
#      'name': 'Hotel',
#      'pluralName': 'Hotels',
#      'shortName': 'Hotel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c7e48a6f0b09c74eee23f7c-34'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bc428d7dce4eee137fb719d',
#    'name': 'Zion Ponderosa Ranch Resort',
#    'location': {'address': 'Twin Knolls Rd',
#     'lat': 37.2750621,
#     'lng': -112.8821911,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.2750621,
#       'lng': -112.8821911}],
#     'distance': 14780,
#     'postalCode': '84758',
#     'cc': 'US',
#     'city': 'Orderville',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Twin Knolls Rd',
#      'Orderville, UT 84758',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d12f951735',
#      'name': 'Resort',
#      'pluralName': 'Resorts',
#      'shortName': 'Resort',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/resort_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bc428d7dce4eee137fb719d-35'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bc428eedce4eee142fb719d',
#    'name': "Flanigan's Inn and Restaurant",
#    'location': {'address': '450 Zion Park Blvd.',
#     'lat': 37.19466391287769,
#     'lng': -112.99372789727026,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19466391287769,
#       'lng': -112.99372789727026}],
#     'distance': 1515,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['450 Zion Park Blvd.',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fa931735',
#      'name': 'Hotel',
#      'pluralName': 'Hotels',
#      'shortName': 'Hotel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bc428eedce4eee142fb719d-36'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '502a9bf2e4b06b23dfc37e3f',
#    'name': "MeMe's Cafe",
#    'location': {'address': '975 Zion Park Blvd',
#     'lat': 37.188437515471264,
#     'lng': -113.0001134902416,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.188437515471264,
#       'lng': -113.0001134902416}],
#     'distance': 652,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['975 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d16d941735',
#      'name': 'Café',
#      'pluralName': 'Cafés',
#      'shortName': 'Café',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-502a9bf2e4b06b23dfc37e3f-37'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5920ee7dda2e0075ae99459b',
#    'name': 'Zion Outfitter',
#    'location': {'lat': 37.19956648316862,
#     'lng': -112.98888134300687,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19956648316862,
#       'lng': -112.98888134300687}],
#     'distance': 2204,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Springdale, UT 84767', 'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b22',
#      'name': 'Outdoor Supply Store',
#      'pluralName': 'Outdoor Supply Stores',
#      'shortName': 'Outdoor Supplies',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5920ee7dda2e0075ae99459b-38'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '51d463e6498e8ee4dbe1d9ee',
#    'name': 'Temple Of Sinawava',
#    'location': {'lat': 37.2842442619694,
#     'lng': -112.9468419938433,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.2842442619694,
#       'lng': -112.9468419938433}],
#     'distance': 12309,
#     'postalCode': '84767',
#     'cc': 'US',
#     'state': 'Utah',
#     'country': 'United States',
#     'formattedAddress': ['UT 84767', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d159941735',
#      'name': 'Trail',
#      'pluralName': 'Trails',
#      'shortName': 'Trail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-51d463e6498e8ee4dbe1d9ee-39'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c086099a1b32d7fd10696f0',
#    'name': 'Zion Canyon Campground',
#    'location': {'address': '479 Zion Park Blvd',
#     'lat': 37.19247255168719,
#     'lng': -112.99085988051161,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.19247255168719,
#       'lng': -112.99085988051161}],
#     'distance': 1468,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['479 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e4941735',
#      'name': 'Campground',
#      'pluralName': 'Campgrounds',
#      'shortName': 'Campground',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/campground_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c086099a1b32d7fd10696f0-40'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4eb720a2e5fa17fc878189d5',
#    'name': 'Zion Natural History Museum',
#    'location': {'crossStreet': 'Zion National Park',
#     'lat': 37.20930773102265,
#     'lng': -112.98012746995438,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.20930773102265,
#       'lng': -112.98012746995438}],
#     'distance': 3536,
#     'cc': 'US',
#     'state': 'Utah',
#     'country': 'United States',
#     'formattedAddress': ['Zion National Park', 'Utah', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d190941735',
#      'name': 'History Museum',
#      'pluralName': 'History Museums',
#      'shortName': 'History Museum',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_history_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4eb720a2e5fa17fc878189d5-41'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c1ee65afcf8c9b60a02ae0b',
#    'name': 'Whiptail Grill',
#    'location': {'address': '445 Zion Park Blvd',
#     'lat': 37.194282371955275,
#     'lng': -112.99283309866007,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.194282371955275,
#       'lng': -112.99283309866007}],
#     'distance': 1520,
#     'postalCode': '84767',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['445 Zion Park Blvd',
#      'Springdale, UT 84767',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c1941735',
#      'name': 'Mexican Restaurant',
#      'pluralName': 'Mexican Restaurants',
#      'shortName': 'Mexican',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '93280226'}},
#   'referralId': 'e-0-4c1ee65afcf8c9b60a02ae0b-42'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4db34260f7b121c29f334f35',
#    'name': 'South Campground',
#    'location': {'address': 'Zion Canyon Scenic Dr',
#     'lat': 37.20301263637583,
#     'lng': -112.98494186827881,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.20301263637583,
#       'lng': -112.98494186827881}],
#     'distance': 2716,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Hurricane',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Zion Canyon Scenic Dr',
#      'Hurricane, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1e4941735',
#      'name': 'Campground',
#      'pluralName': 'Campgrounds',
#      'shortName': 'Campground',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/campground_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4db34260f7b121c29f334f35-43'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5bedcbe73e6741002ce2d38b',
#    'name': 'Rosita’s',
#    'location': {'lat': 37.16236,
#     'lng': -113.017365,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.16236,
#       'lng': -113.017365}],
#     'distance': 2647,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Springdale',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Springdale, UT 84737', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c1941735',
#      'name': 'Mexican Restaurant',
#      'pluralName': 'Mexican Restaurants',
#      'shortName': 'Mexican',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
# ...
#      'Hurricane, UT 84737',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b42',
#      'name': 'Big Box Store',
#      'pluralName': 'Big Box Stores',
#      'shortName': 'Big Box Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4b67bbf5f964a520505c2be3-84'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4c201f76b306c9281c8d69b7',
#    'name': "Farmer's Market",
#    'location': {'lat': 37.21043627964572,
#     'lng': -113.27355387795068,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.21043627964572,
#       'lng': -113.27355387795068}],
#     'distance': 24264,
#     'postalCode': '84745',
#     'cc': 'US',
#     'city': 'La Verkin',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['La Verkin, UT 84745', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d118951735',
#      'name': 'Grocery Store',
#      'pluralName': 'Grocery Stores',
#      'shortName': 'Grocery Store',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4c201f76b306c9281c8d69b7-85'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e053cd7b0fbba5eee0e135c',
#    'name': "Papa Murphy's",
#    'location': {'address': '535 W State St',
#     'lat': 37.1762994,
#     'lng': -113.2987578,
#     'labeledLatLngs': [{'label': 'entrance',
#       'lat': 37.176315,
#       'lng': -113.29872},
#      {'label': 'display', 'lat': 37.1762994, 'lng': -113.2987578}],
#     'distance': 26319,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Hurricane',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['535 W State St',
#      'Hurricane, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e053cd7b0fbba5eee0e135c-86'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bbca66007809521fc87d991',
#    'name': 'Subway',
#    'location': {'address': '525 W State St',
#     'lat': 37.17630043519847,
#     'lng': -113.29837270650329,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.17630043519847,
#       'lng': -113.29837270650329}],
#     'distance': 26285,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Hurricane',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['525 W State St',
#      'Hurricane, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1c5941735',
#      'name': 'Sandwich Place',
#      'pluralName': 'Sandwich Places',
#      'shortName': 'Sandwiches',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/deli_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bbca66007809521fc87d991-87'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4d41f106aed776eb1bd66997',
#    'name': "Domino's Pizza",
#    'location': {'address': '410 W State St',
#     'lat': 37.1767947,
#     'lng': -113.2958718,
#     'labeledLatLngs': [{'label': 'entrance',
#       'lat': 37.176748,
#       'lng': -113.295867},
#      {'label': 'display', 'lat': 37.1767947, 'lng': -113.2958718}],
#     'distance': 26062,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Hurricane',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['410 W State St',
#      'Hurricane, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ca941735',
#      'name': 'Pizza Place',
#      'pluralName': 'Pizza Places',
#      'shortName': 'Pizza',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4d41f106aed776eb1bd66997-88'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4cfefd0666ee9eb0fa28a74e',
#    'name': 'U.S. Bank ATM',
#    'location': {'address': '1060 W State St',
#     'lat': 37.176792,
#     'lng': -113.307938,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.176792,
#       'lng': -113.307938},
#      {'label': 'entrance', 'lat': 37.1767, 'lng': -113.307921}],
#     'distance': 27131,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Hurricane',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['1060 W State St',
#      'Hurricane, UT 84737',
#      'United States']},
#    'categories': [{'id': '52f2ab2ebcbc57f1066b8b56',
#      'name': 'ATM',
#      'pluralName': 'ATMs',
#      'shortName': 'ATM',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/financial_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4cfefd0666ee9eb0fa28a74e-89'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ab86c61f964a520f87c20e3',
#    'name': 'Rodeway Inn',
#    'location': {'address': '650 W State St',
#     'lat': 37.176729,
#     'lng': -113.2988775,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.176729,
#       'lng': -113.2988775},
#      {'label': 'entrance', 'lat': 37.176694, 'lng': -113.298874}],
#     'distance': 26328,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Hurricane',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['650 W State St',
#      'Hurricane, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1fb931735',
#      'name': 'Motel',
#      'pluralName': 'Motels',
#      'shortName': 'Motel',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4ab86c61f964a520f87c20e3-90'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4ded5021e4cd032b18887094',
#    'name': 'United States Postal Service',
#    'location': {'address': '55 S Central St',
#     'lat': 36.989005129122525,
#     'lng': -112.97441556120248,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 36.989005129122525,
#       'lng': -112.97441556120248}],
#     'distance': 21713,
#     'postalCode': '86021',
#     'cc': 'US',
#     'city': 'Colorado City',
#     'state': 'AZ',
#     'country': 'United States',
#     'formattedAddress': ['55 S Central St',
#      'Colorado City, AZ 86021',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d172941735',
#      'name': 'Post Office',
#      'pluralName': 'Post Offices',
#      'shortName': 'Post Office',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/postoffice_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4ded5021e4cd032b18887094-91'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e2096521f6effe84f6846a0',
#    'name': 'Maverik',
#    'location': {'address': '460 North State Street',
#     'lat': 37.2102072,
#     'lng': -113.2712905,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.2102072,
#       'lng': -113.2712905}],
#     'distance': 24062,
#     'postalCode': '84745',
#     'cc': 'US',
#     'city': 'La Verkin',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['460 North State Street',
#      'La Verkin, UT 84745',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d113951735',
#      'name': 'Gas Station',
#      'pluralName': 'Gas Stations',
#      'shortName': 'Gas Station',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '568476353'}},
#   'referralId': 'e-0-4e2096521f6effe84f6846a0-92'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4e332e247d8b6946c1ebcbaa',
#    'name': 'Coral Pink Sand Dunes State Park',
#    'location': {'lat': 37.14523596925176,
#     'lng': -112.56898416173908,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.14523596925176,
#       'lng': -112.56898416173908}],
#     'distance': 38650,
#     'cc': 'US',
#     'city': 'Kanab',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Kanab, UT', 'United States']},
#    'categories': [{'id': '5bae9231bedf3950379f89d0',
#      'name': 'State / Provincial Park',
#      'pluralName': 'State / Provincial Parks',
#      'shortName': 'State / Provincial Park',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/default_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4e332e247d8b6946c1ebcbaa-93'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bb9e14c7421a593c319c340',
#    'name': 'Maverik #402',
#    'location': {'address': '55 N 3400 W',
#     'lat': 37.17010489724265,
#     'lng': -113.36769714030191,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.17010489724265,
#       'lng': -113.36769714030191},
#      {'label': 'entrance', 'lat': 37.170061, 'lng': -113.367607}],
#     'distance': 32456,
#     'postalCode': '84737',
#     'cc': 'US',
#     'city': 'Hurricane',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['55 N 3400 W',
#      'Hurricane, UT 84737',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d113951735',
#      'name': 'Gas Station',
#      'pluralName': 'Gas Stations',
#      'shortName': 'Gas Station',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []},
#    'venuePage': {'id': '559255208'}},
#   'referralId': 'e-0-4bb9e14c7421a593c319c340-94'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4cb34bd675ebb60c3524dbad',
#    'name': 'Silver Reef Museum',
#    'location': {'address': 'Silver Reef Dr',
#     'crossStreet': 'Wells Fargo',
#     'lat': 37.25313186645508,
#     'lng': -113.36817932128906,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.25313186645508,
#       'lng': -113.36817932128906}],
#     'distance': 33381,
#     'cc': 'US',
#     'city': 'Leeds',
#     'state': 'UT',
#     'country': 'United States',
#     'formattedAddress': ['Silver Reef Dr (Wells Fargo)',
#      'Leeds, UT',
#      'United States']},
#    'categories': [{'id': '4bf58dd8d48988d181941735',
#      'name': 'Museum',
#      'pluralName': 'Museums',
#      'shortName': 'Museum',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4cb34bd675ebb60c3524dbad-95'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '523df906498e9c0a2984ac2a',
#    'name': 'Colorado City Municipal Airport',
#    'location': {'lat': 36.99596396472061,
#     'lng': -113.00373823295855,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 36.99596396472061,
#       'lng': -113.00373823295855}],
#     'distance': 20799,
#     'cc': 'US',
#     'city': 'Colorado City',
#     'state': 'AZ',
#     'country': 'United States',
#     'formattedAddress': ['Colorado City, AZ', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d1ed931735',
#      'name': 'Airport',
#      'pluralName': 'Airports',
#      'shortName': 'Airport',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/airport_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-523df906498e9c0a2984ac2a-96'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5b4ea00792e7a9002ccc0a55',
#    'name': 'Edge Of The World Brewery',
#    'location': {'address': '70 N Central St.',
#     'lat': 36.991281,
#     'lng': -112.973656,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 36.991281,
#       'lng': -112.973656}],
#     'distance': 21469,
#     'postalCode': '86021',
#     'cc': 'US',
#     'city': 'Colorado City',
#     'state': 'AZ',
#     'country': 'United States',
#     'formattedAddress': ['70 N Central St.',
#      'Colorado City, AZ 86021',
#      'United States']},
#    'categories': [{'id': '50327c8591d4c4b30a586d5d',
#      'name': 'Brewery',
#      'pluralName': 'Breweries',
#      'shortName': 'Brewery',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5b4ea00792e7a9002ccc0a55-97'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '4bb928851261d13a3465e998',
#    'name': "Dixie Nat'l Forest @ Silver Reef",
#    'location': {'lat': 37.27272323403318,
#     'lng': -113.38871827265274,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.27272323403318,
#       'lng': -113.38871827265274}],
#     'distance': 35698,
#     'cc': 'US',
#     'state': 'Utah',
#     'country': 'United States',
#     'formattedAddress': ['Utah', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d159941735',
#      'name': 'Trail',
#      'pluralName': 'Trails',
#      'shortName': 'Trail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-4bb928851261d13a3465e998-98'},
#  {'reasons': {'count': 0,
#    'items': [{'summary': 'This spot is popular',
#      'type': 'general',
#      'reasonName': 'globalInteractionReason'}]},
#   'venue': {'id': '5401edfa498e46786b10f27d',
#    'name': 'Hurricane Sand Dunes',
#    'location': {'lat': 37.078962,
#     'lng': -113.392777,
#     'labeledLatLngs': [{'label': 'display',
#       'lat': 37.078962,
#       'lng': -113.392777}],
#     'distance': 36546,
#     'cc': 'US',
#     'state': 'Utah',
#     'country': 'United States',
#     'formattedAddress': ['Utah', 'United States']},
#    'categories': [{'id': '4bf58dd8d48988d159941735',
#      'name': 'Trail',
#      'pluralName': 'Trails',
#      'shortName': 'Trail',
#      'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#       'suffix': '.png'},
#      'primary': True}],
#    'photos': {'count': 0, 'groups': []}},
#   'referralId': 'e-0-5401edfa498e46786b10f27d-99'}]

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues
# Out:
# C:\Users\horan\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                  name                  categories        lat  \
# 0               King's Landing Bistro         American Restaurant  37.179922
# 1                  Zion National Park               National Park  37.199275
# 2   Zion National Park Visitor Center  Tourist Information Center  37.200271
# 3                    Desert Pearl Inn                      Resort  37.190510
# 4                   Deep Creek Coffee                 Coffee Shop  37.188994
# ..                                ...                         ...        ...
# 95                 Silver Reef Museum                      Museum  37.253132
# 96    Colorado City Municipal Airport                     Airport  36.995964
# 97          Edge Of The World Brewery                     Brewery  36.991281
# 98   Dixie Nat'l Forest @ Silver Reef                       Trail  37.272723
# 99               Hurricane Sand Dunes                       Trail  37.078962
#
#            lng
# 0  -113.006233
# 1  -112.989049
# 2  -112.986939
# 3  -112.994420
# 4  -113.000009
# ..         ...
# 95 -113.368179
# 96 -113.003738
# 97 -112.973656
# 98 -113.388718
# 99 -113.392777
#
# [100 rows x 4 columns]
